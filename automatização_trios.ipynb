# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.stats.stats import pearsonr
# Out:
# C:\Users\LuizF\AppData\Local\Temp\ipykernel_11364\1270347195.py:5: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import pearsonr

# %%
os.chdir(r'E:\Documentos\Pesquisas Acadêmicas\Oceanografia Bio-Optica\Tarefas do dia 30-10-2022\Experimentos 1 Sensor\Geometria 4')
df1 = pd.read_table('Geometria 4', skiprows=44)
df1 = df1.replace('+NAN', np.nan) #Criando NaN para NaN "falsos"
df1 = df1.dropna() #removendo linhas em branco "NaN"
df1_col = [i for i in df1.columns]
df1_col_l = ['Wavelength'] + ['E'+str(i) for i in range(1, len(df1_col))] #Código que percorre o número de colunas
df1.columns = df1_col_l #renomeando conforme o número de colunas
df1
# Out:
#           Wavelength                E1                E2                E3  \
# 4    318.78891279224  20.2807369822974  19.5749413538447  19.4575695752772
# 5    322.10811761777  26.9075951096816  27.1227229092912  27.6597902132115
# 6    325.42816205568  37.5537235515231  36.7950193203404  37.2084623526293
# 7    328.74903388631  46.3631433508347  45.8979432967281  46.3333054464897
# 8       332.07072089  52.8083305743288  52.8989446529072  53.5613208047693
# ..               ...               ...               ...               ...
# 190  937.71186732032  19.3314464598315  16.6456505996612  17.7435394385761
# 191  940.97700079823  22.6760955376227  14.1820675998886  20.6459115278328
# 192  944.24070103176  22.6359585968368  18.1508442069251  20.2448190299501
# 193  947.50295580125  24.7008110202334  19.6104749854703  23.4988255554103
# 194  950.76375288704  22.5019985123763  17.5737105781586  20.2846486251782
#
# ...

# %%
df1
