# %%
import pandas as pd #biblioteca para ler dados tabulados
import matplotlib.pyplot as plt #biblioteca para apresentar gráfico
import numpy as np #biblioteca de estatística 
import os #biblitoeca para acessar as pastas
from scipy.stats.stats import pearsonr

# %%
os.chdir('/home/bruno/git/biotica_usp/exp1_sensor/')
g1 = pd.read_table('Geometria_1', skiprows=44).dropna() #selecionando arquivo
g1 = g1.replace('+NAN', np.nan) #Criando NaN para NaN "falsos"
g1 = g1.dropna() #removendo linhas em branco "NaN"
g1.columns = [['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6']] #Renomeando colunas
g1 = g1.reset_index() #Resetando o index 
g1 = g1[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6']] #Selecionando colunas de interesse
g1.to_excel('Geometria_1.xlsx')

g1r = pd.read_table('Geometria_1_rep', skiprows=41).dropna() #selecionando arquivo
g1r = g1r.replace('+NAN', np.nan) #Criando NaN para NaN "falsos"
g1r = g1r.dropna() #removendo linhas em branco "NaN"
g1r.columns = [['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7']] #Renomeando colunas
g1r = g1r.reset_index() #Resetando o index 
g1r = g1r[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7']] #Selecionando colunas de interesse
g1r.to_excel('Geometria_1_replica.xlsx')

g1t = pd.read_table('Geometria_1_Treplica', skiprows=41).dropna() #selecionando arquivo
g1t = g1t.replace('+NAN', np.nan) #Criando NaN para NaN "falsos"
g1t = g1t.dropna() #removendo linhas em branco "NaN"
g1t.columns = [['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6']] #Renomeando colunas
g1t = g1t.reset_index() #Resetando o index 
g1t = g1t[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6']] #Selecionando colunas de interesse
g1t.to_excel('Geometria_1_treplica.xlsx')

# %%
g1 = pd.read_excel('Geometria_1.xlsx').dropna()
g1 = g1[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6']]
g1_stats = g1[['E1', 'E2', 'E3', 'E4', 'E5', 'E6']]
g1['mean'] = g1_stats.mean(axis=1)
g1['median'] = g1_stats.median(axis=1)
g1['std'] = g1_stats.std(axis=1)

g1r = pd.read_excel('Geometria_1_replica.xlsx').dropna()
g1r = g1r[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7']]
g1r_stats = g1r[['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7']]
g1r['mean'] = g1r_stats.mean(axis=1)
g1r['median'] = g1r_stats.median(axis=1)
g1r['std'] = g1r_stats.std(axis=1)

g1t = pd.read_excel('Geometria_1_treplica.xlsx').dropna()
g1t = g1t[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6']]
g1t_stats = g1t[['E1', 'E2', 'E3', 'E4', 'E5', 'E6']]
g1t['mean'] = g1t_stats.mean(axis=1)
g1t['median'] = g1t_stats.median(axis=1)
g1t['std'] = g1t_stats.std(axis=1)

# %%
fig, ax = plt.subplots(figsize=(12,8))
# plt.plot(df1['Wavelenght'], df1['E1'], label='E1')
# plt.plot(df1['Wavelenght'], df1['E2'], label='E2')
# plt.plot(df1['Wavelenght'], df1['E3'], label='E3')
# plt.plot(df1['Wavelenght'], df1['E4'], label='E4')
# plt.plot(df1['Wavelenght'], df1['E5'], label='E5')
# plt.plot(df1['Wavelenght'], df1['E5'], label='E6')
plt.plot(g1['Wavelenght'], df1['mean'], ':', label='Mean')
plt.plot(g1['Wavelenght'], df1['median'], '--', label='Median', color='black')
plt.plot(g1['Wavelenght'], df1['std'], ':', label='Standard Deviation', color='gray')
plt.grid()
plt.legend()

# %%
fig, ax = plt.subplots(figsize=(12,8))
# plt.plot(df2['Wavelenght'], df2['E1'], label='E1')
# plt.plot(df2['Wavelenght'], df2['E2'], label='E2')
# plt.plot(df2['Wavelenght'], df2['E3'], label='E3')
# plt.plot(df2['Wavelenght'], df2['E4'], label='E4')
# plt.plot(df2['Wavelenght'], df2['E5'], label='E5')
# plt.plot(df2['Wavelenght'], df2['E6'], label='E6')
# plt.plot(df2['Wavelenght'], df2['E7'], label='E7')
plt.plot(g1r['Wavelenght'], df2['mean'], ':', label='Mean')
plt.plot(g1r['Wavelenght'], df2['median'], '--', label='Median', color='black')
plt.plot(g1r['Wavelenght'], df2['std'], ':', label='Standard Deviation', color='gray')
plt.grid()
plt.legend()

# %%
fig, ax = plt.subplots(figsize=(12,8))
# plt.plot(df3['Wavelenght'], df3['E1'], label='E1')
# plt.plot(df3['Wavelenght'], df3['E2'], label='E2')
# plt.plot(df3['Wavelenght'], df3['E3'], label='E3')
# plt.plot(df3['Wavelenght'], df3['E4'], label='E4')
# plt.plot(df3['Wavelenght'], df3['E5'], label='E5')
plt.plot(g1t['Wavelenght'], df3['mean'], ':', label='Mean')
plt.plot(g1t['Wavelenght'], df3['median'], '--', label='Median', color='black')
plt.plot(g1t['Wavelenght'], df3['std'], ':', label='Standard Deviation', color='gray')
plt.grid()
plt.legend()

# %%
fig, ax = plt.subplots(figsize=(16, 10))

plt.subplot(231)
plt.scatter(g1['median'], g1r['median'])
plt.xlabel('Geometria 1 (W/m²)')
plt.ylabel('Geometria 1 - Replica (W/m²)')
plt.plot(g1['median'], np.polyval(np.polyfit(g1['median'], g1r['median'], 1), g1['median']), color='red')
plt.text(50, 200, 'R² = '+str("%.4f" %pearsonr(g1['median'], g1r['median'])[0]**2), dict(size=10))

plt.subplot(232)
plt.scatter(g1['median'], g1t['median'])
plt.xlabel('Geometria 1 (W/m²)')
plt.ylabel('Geometria 1 - Treplica (W/m²)')
plt.plot(df1['median'], np.polyval(np.polyfit(g1['median'], g1t['median'], 1), g1['median']), color='red')
plt.text(50, 110, 'R² = '+str("%.4f" %pearsonr(g1['median'], g1t['median'])[0]**2), dict(size=10))

plt.subplot(233)
plt.scatter(g1r['median'], g1t['median'])
plt.xlabel('Geometria 1 - Replica (W/m²)')
plt.ylabel('Geometria 1 - Treplica (W/m²)')
plt.plot(df2['median'], np.polyval(np.polyfit(g1r['median'], g1t['median'], 1), g1r['median']), color='red')
plt.text(25, 110, 'R² = '+str("%.4f" %pearsonr(g1r['median'], g1t['median'])[0]**2), dict(size=10))

plt.subplot(234)
plt.scatter(g1['mean'], g1r['mean'])
plt.xlabel('Geometria 1 (W/m²)')
plt.ylabel('Geometria 1 - Replica (W/m²)')
plt.plot(df1['mean'], np.polyval(np.polyfit(g1['mean'], g1r['mean'], 1), g1['mean']), color='red')
plt.text(50, 200, 'R² = '+str("%.4f" %pearsonr(g1['mean'], g1r['mean'])[0]**2), dict(size=10))

plt.subplot(235)
plt.scatter(g1['mean'], g1t['mean'])
plt.xlabel('Geometria 1 (W/m²)')
plt.ylabel('Geometria 1 - Treplica (W/m²)')
plt.plot(df1['mean'], np.polyval(np.polyfit(g1['mean'], g1t['mean'], 1), g1['mean']), color='red')
plt.text(50, 110, 'R² = '+str("%.4f" %pearsonr(g1['mean'], g1t['mean'])[0]**2), dict(size=10))

plt.subplot(236)
plt.scatter(g1r['mean'], g1t['mean'])
plt.xlabel('Geometria 1 - Replica (W/m²)')
plt.ylabel('Geometria 1 - Treplica (W/m²)')
plt.plot(df2['mean'], np.polyval(np.polyfit(g1r['mean'], g1t['mean'], 1), g1r['mean']), color='red')
plt.text(25, 110, 'R² = '+str("%.4f" %pearsonr(g1r['mean'], g1t['mean'])[0]**2), dict(size=10))
# Out:
# Text(25, 110, 'R² = 0.9654')

# %%
### médias das medidas na geometria1

# %%
### geometria 2

# %%
os.chdir('/home/bruno/git/biotica_usp/exp1_sensor/')
g2 = pd.read_table('Geometria_2', skiprows=44).dropna() #selecionando arquivo
g2 = g2.replace('+NAN', np.nan) #Criando NaN para NaN "falsos"
g2 = g2.dropna() #removendo linhas em branco "NaN"
g2.columns = [['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5']] #Renomeando colunas
g2 = g2.reset_index() #Resetando o index 
g2 = g2[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5']] #Selecionando colunas de interesse
g2.to_excel('Geometria_2.xlsx')

g2r = pd.read_table('Geometria_2_Replica', skiprows=41).dropna() #selecionando arquivo
g2r = g2r.replace('+NAN', np.nan) #Criando NaN para NaN "falsos"
g2r = g2r.dropna() #removendo linhas em branco "NaN"
g2r.columns = [['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8']] #Renomeando colunas
g2r = g2r.reset_index() #Resetando o index 
g2r = g2r[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8']] #Selecionando colunas de interesse
g2r.to_excel('Geometria_2_replica.xlsx')

g2t = pd.read_table('Geometria_2_Treplica', skiprows=41).dropna() #selecionando arquivo
g2t = g2t.replace('+NAN', np.nan) #Criando NaN para NaN "falsos"
g2t = g2t.dropna() #removendo linhas em branco "NaN"
g2t.columns = [['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5']] #Renomeando colunas
g2t = g2t.reset_index() #Resetando o index 
g2t = g2t[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5']] #Selecionando colunas de interesse
g2t.to_excel('Geometria_2_treplica.xlsx')

# %%
g2 = pd.read_excel('Geometria_2.xlsx').dropna()
g2 = g2[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5']]
g2_stats = g2[['E1', 'E2', 'E3', 'E4', 'E5']]
g2['mean'] = g2_stats.mean(axis=1)
g2['median'] = g2_stats.median(axis=1)
g2['std'] = g2_stats.std(axis=1)

g2r = pd.read_excel('Geometria_2_replica.xlsx').dropna()
g2r = g2r[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', ' E8']]
g2r_stats = g2r[['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8']]
g2r['mean'] = g2r_stats.mean(axis=1)
g2r['median'] = g2r_stats.median(axis=1)
g2r['std'] = g2r_stats.std(axis=1)

g2t = pd.read_excel('Geometria_2_treplica.xlsx').dropna()
g2t = g2t[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5']]
g2t_stats = g2t[['E1', 'E2', 'E3', 'E4', 'E5']]
g2t['mean'] = g2t_stats.mean(axis=1)
g2t['median'] = g2t_stats.median(axis=1)
g2t['std'] = g2t_stats.std(axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7226/4227921310.py in <module>
#       7
#       8 df2 = pd.read_excel('Geometria_2_replica.xlsx').dropna()
# ----> 9 df2 = df2[['Wavelenght', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', ' E8']]
#      10 df2_stats = df2[['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8']]
#      11 df2['mean'] = df2_stats.mean(axis=1)
#
# ~/miniconda3/envs/ocean/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/miniconda3/envs/ocean/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))
# plt.plot(df1['Wavelenght'], df1['E1'], label='E1')
# plt.plot(df1['Wavelenght'], df1['E2'], label='E2')
# plt.plot(df1['Wavelenght'], df1['E3'], label='E3')
# plt.plot(df1['Wavelenght'], df1['E4'], label='E4')
# plt.plot(df1['Wavelenght'], df1['E5'], label='E5')
# plt.plot(df1['Wavelenght'], df1['E5'], label='E6')
plt.plot(g2['Wavelenght'], g2['mean'], ':', label='Mean')
plt.plot(g2['Wavelenght'], g2['median'], '--', label='Median', color='black')
plt.plot(g2['Wavelenght'], g2['std'], ':', label='Standard Deviation', color='gray')
plt.grid()
plt.legend()

# %%
fig, ax = plt.subplots(figsize=(12,8))
# plt.plot(df1['Wavelenght'], df1['E1'], label='E1')
# plt.plot(df1['Wavelenght'], df1['E2'], label='E2')
# plt.plot(df1['Wavelenght'], df1['E3'], label='E3')
# plt.plot(df1['Wavelenght'], df1['E4'], label='E4')
# plt.plot(df1['Wavelenght'], df1['E5'], label='E5')
# plt.plot(df1['Wavelenght'], df1['E5'], label='E6')
plt.plot(g2r['Wavelenght'], g2r['mean'], ':', label='Mean')
plt.plot(g2r['Wavelenght'], g2r['median'], '--', label='Median', color='black')
plt.plot(g2r['Wavelenght'], g2r['std'], ':', label='Standard Deviation', color='gray')
plt.grid()
plt.legend()

# %%
fig, ax = plt.subplots(figsize=(12,8))
# plt.plot(df1['Wavelenght'], df1['E1'], label='E1')
# plt.plot(df1['Wavelenght'], df1['E2'], label='E2')
# plt.plot(df1['Wavelenght'], df1['E3'], label='E3')
# plt.plot(df1['Wavelenght'], df1['E4'], label='E4')
# plt.plot(df1['Wavelenght'], df1['E5'], label='E5')
# plt.plot(df1['Wavelenght'], df1['E5'], label='E6')
plt.plotg2t['Wavelenght'], g2t['mean'], ':', label='Mean')
plt.plotg2t['Wavelenght'], g2t['median'], '--', label='Median', color='black')
plt.plotg2t['Wavelenght'], g2t['std'], ':', label='Standard Deviation', color='gray')
plt.grid()
plt.legend()

# %%
### geometria 3

# %%
### geometria 4
